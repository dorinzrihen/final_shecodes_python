# %%
import pandas as pd

# %%
df = pd.read_excel("reports.xlsx")
df
# Out:
#    day                                   department  entry_hour  entry_minute  \
# 0   22                                          web          18            55
# 1   12                                          NaN          18            58
# 2   12                                          NaN          19             1
# 3   12                                          NaN          19            57
# 4   12                                          NaN          20            15
# 5   12                                          NaN          20            40
# 6   12  9    store\nName: department, dtype: object          21            28
# 7   12  9    store\nName: department, dtype: object          21            40
#
#    exit_hour  exit_minute                                 first_name  \
# 0        NaN          NaN                                      dorin
# 1        NaN          NaN                                        NaN
# ...

# %%
x= df.loc[(df["id"] == 55555) & (df["day"] == 22)]
x
df.loc[0].at['day']
# Out:
#    day department  entry_hour  entry_minute  exit_hour  exit_minute  \
# 0   22        web          18            55        NaN          NaN
#
#   first_name     id last_name manager manager_id  month   position  sick_day  \
# 0      dorin  55555    zrihen   benni        NaN     12  photoshop       NaN
#
#    sum  vecation_day  year
# 0  NaN           NaN  2020

# %%
# Out:
#         id first_name  last_name        position manager  manager_id  \
# 1   666666       eyal      cohen          seller   kiril    565686.0
# 2   777777      benni       levi          seller   kiril    565686.0
# 3   888888      yaron      levon          seller   kiril    565686.0
# 4   565685     shoval     zarhin          seller   kiril    565686.0
# 5   565686      kiril     zrihen  seller-manager   yossi    565689.0
# 6   565687       maya     zrihen  seller-manager   yossi    565689.0
# 7   565688      ronen      tamar  seller-manager   yossi    565690.0
# 8   565689      yossi      timor         manager     NaN         NaN
# 9   565690        gal  brn-moyal         manager     NaN         NaN
# 10    7070        Dor        Dor             NaN    roee    656565.0
# 11    6060        eli      cohen             NaN     NaN         NaN
#
#    department
# 1     website
# 2     website
# 3     website
# 4       store
# 5       store
# 6       store
# 7       store
# ...
